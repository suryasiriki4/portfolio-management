# %%
import pandas as pd
import numpy as np
import datetime

# %%
import pyfolio
# Out:
# /home/surya/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy/venv/lib/python3.6/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline

# %%
def get_daily_return(df):
    df['daily_return']=df.account_value.pct_change(1)
    #df=df.dropna()
    print('Sharpe: ',(252**0.5)*df['daily_return'].mean()/ df['daily_return'].std())
    return df

# %%
def backtest_strat(df):
    strategy_ret= df.copy()
    strategy_ret['Date'] = pd.to_datetime(strategy_ret['Date'])
    strategy_ret.set_index('Date', drop = False, inplace = True)
    strategy_ret.index = strategy_ret.index.tz_localize('UTC')
    del strategy_ret['Date']
    ts = pd.Series(strategy_ret['daily_return'].values, index=strategy_ret.index)
    return ts

# %%
def get_account_value(model_name):
    df_account_value=pd.DataFrame()
    for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
        temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format(model_name,i))
        df_account_value = df_account_value.append(temp,ignore_index=True)
    df_account_value = pd.DataFrame({'account_value':df_account_value['0']})
    sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
    print(sharpe)
    df_account_value=df_account_value.join(df_trade_date[63:].reset_index(drop=True))
    return df_account_value

# %% [markdown]
# ## DJIA

# %%
dji = pd.read_csv("data/^DJI.csv")
test_dji=dji[(dji['Date']>='2016-01-01') & (dji['Date']<='2020-06-30')]
test_dji = test_dji.reset_index(drop=True)

# %%
test_dji.shape
# Out:
# (1131, 7)

# %%
test_dji.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-01-04  17405.480469  17405.480469  16957.630859  17148.939453
# 1  2016-01-05  17147.500000  17195.839844  17038.609375  17158.660156
# 2  2016-01-06  17154.830078  17154.830078  16817.619141  16906.509766
# 3  2016-01-07  16888.359375  16888.359375  16463.630859  16514.099609
# 4  2016-01-08  16519.169922  16651.890625  16314.570313  16346.450195
#
#       Adj Close     Volume
# 0  17148.939453  148060000
# 1  17158.660156  105750000
# 2  16906.509766  120250000
# 3  16514.099609  176240000
# 4  16346.450195  141850000

# %%
test_dji['daily_return']=test_dji['Adj Close'].pct_change(1)

# %%
dow_strat = backtest_strat(test_dji)

# %% [markdown]
# ## Ensemble Strategy

# %%
df=pd.read_csv('data/dow_30_2009_2020.csv')

# %%
rebalance_window = 63
validation_window = 63
unique_trade_date = df[(df.datadate > 20151001)&(df.datadate <= 20200707)].datadate.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

# %%
ensemble_account_value = get_account_value('ensemble_pickle')
ensemble_account_value_nlp = get_account_value('ensemble_pickle_nlp')
# Out:
# 1.2683594347899967
# 0.605734115645353

# %%
ensemble_account_value.account_value.plot(legend=True)
ensemble_account_value_nlp.account_value.plot(legend=True)

# %%
ensemble_account_value = get_daily_return(ensemble_account_value)
ensemble_account_value_nlp = get_daily_return(ensemble_account_value_nlp)
# Out:
# Sharpe:  1.2683594347899967
# Sharpe:  0.605734115645353

# %%
ensemble_account_value['Date'] = test_dji['Date']
ensemble_account_value_nlp['Date'] = test_dji['Date']

# %%
ensemble_account_value.head()
ensemble_account_value_nlp.head()
# Out:
#     account_value  datadate  daily_return        Date
# 0  1000000.000000  20160104           NaN  2016-01-04
# 1   999656.103329  20160105     -0.000344  2016-01-05
# 2   997712.084422  20160106     -0.001945  2016-01-06
# 3   993635.677679  20160107     -0.004086  2016-01-07
# 4   991759.612309  20160108     -0.001888  2016-01-08

# %%
ensemble_strat = backtest_strat(ensemble_account_value[0:1097])
ensemble_strat_nlp = backtest_strat(ensemble_account_value_nlp[0:1097])

# %%
with pyfolio.plotting.plotting_context(font_scale=1.1):
    pyfolio.create_full_tear_sheet(returns = ensemble_strat,
                                   benchmark_rets=dow_strat, set_context=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-12</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>52</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.802%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>50.24%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>7.541%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.74</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-5.645%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.34</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.35</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.912%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.08</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.64</td>
#       <td>2016-06-23</td>
#       <td>2016-06-27</td>
#       <td>2016-07-12</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.13</td>
#       <td>2016-07-14</td>
#       <td>2016-11-04</td>
#       <td>2016-11-22</td>
#       <td>94</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.87</td>
#       <td>2019-02-25</td>
#       <td>2019-03-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.28</td>
#       <td>2016-01-04</td>
#       <td>2016-02-11</td>
#       <td>2016-02-17</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.27</td>
#       <td>2016-04-19</td>
#       <td>2016-05-19</td>
#       <td>2016-06-23</td>
#       <td>48</td>
#     </tr>
#   </tbody>
# </table>
# /home/surya/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy/venv/lib/python3.6/site-packages/pyfolio/tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)

# %%
with pyfolio.plotting.plotting_context(font_scale=1.1):
    pyfolio.create_full_tear_sheet(returns = ensemble_strat_nlp,
                                   benchmark_rets=dow_strat, set_context=False)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2016-01-04</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-05-12</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>52</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.954%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>23.428%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.54%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.48</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.56</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-10.314%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.055%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.04</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.13</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10.31</td>
#       <td>2019-02-26</td>
#       <td>2020-04-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.71</td>
#       <td>2016-04-19</td>
#       <td>2016-06-27</td>
#       <td>2016-12-13</td>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.34</td>
#       <td>2018-06-11</td>
#       <td>2018-06-27</td>
#       <td>2019-01-30</td>
#       <td>168</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3.72</td>
#       <td>2016-01-04</td>
#       <td>2016-02-11</td>
#       <td>2016-02-17</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.10</td>
#       <td>2019-01-30</td>
#       <td>2019-02-11</td>
#       <td>2019-02-19</td>
#       <td>15</td>
#     </tr>
#   </tbody>
# </table>
# /home/surya/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy/venv/lib/python3.6/site-packages/pyfolio/tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)
